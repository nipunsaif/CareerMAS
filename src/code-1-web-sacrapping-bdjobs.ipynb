# %%
# !pip install pandas requests beautifulsoup4 nest_asyncio playwright
# !playwright install
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (4.13.4)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.11/dist-packages (1.6.0)
# Collecting playwright
#   Downloading playwright-1.54.0-py3-none-manylinux1_x86_64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.6.15)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (4.14.0)
# Collecting pyee<14,>=13 (from playwright)
#   Downloading pyee-13.0.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: greenlet<4.0.0,>=3.1.1 in /usr/local/lib/python3.11/dist-packages (from playwright) (3.2.3)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.2->pandas) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.2->pandas) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.2->pandas) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.2->pandas) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.2->pandas) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.2->pandas) (2.4.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.23.2->pandas) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.23.2->pandas) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.23.2->pandas) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.23.2->pandas) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.23.2->pandas) (2024.2.0)
# Downloading playwright-1.54.0-py3-none-manylinux1_x86_64.whl (45.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 MB 39.0 MB/s eta 0:00:00:00:0100:01
# Downloading pyee-13.0.0-py3-none-any.whl (15 kB)
# Installing collected packages: pyee, playwright
# Successfully installed playwright-1.54.0 pyee-13.0.0
# Downloading Chromium 139.0.7258.5 (playwright build v1181) from https://cdn.playwright.dev/dbazure/download/playwright/builds/chromium/1181/chromium-linux.zip
# 172.5 MiB [                    ] 0% 0.0s172.5 MiB [                    ] 0% 28.3s172.5 MiB [                    ] 0% 23.4s172.5 MiB [                    ] 0% 13.6s172.5 MiB [                    ] 0% 8.0s172.5 MiB [                    ] 1% 7.7s172.5 MiB [                    ] 1% 6.3s172.5 MiB [                    ] 2% 4.4s172.5 MiB [=                   ] 3% 3.2s172.5 MiB [=                   ] 4% 2.8s172.5 MiB [=                   ] 5% 2.8s172.5 MiB [=                   ] 6% 2.5s172.5 MiB [==                  ] 8% 2.2s172.5 MiB [==                  ] 9% 2.1s172.5 MiB [==                  ] 10% 2.0s172.5 MiB [==                  ] 11% 1.9s172.5 MiB [==                  ] 12% 1.9s172.5 MiB [===                 ] 13% 1.8s172.5 MiB [===                 ] 14% 1.7s172.5 MiB [===                 ] 16% 1.6s172.5 MiB [====                ] 18% 1.5s172.5 MiB [====                ] 19% 1.4s172.5 MiB [====                ] 21% 1.4s172.5 MiB [====                ] 22% 1.3s172.5 MiB [=====               ] 22% 1.3s172.5 MiB [=====               ] 24% 1.2s172.5 MiB [=====               ] 26% 1.2s172.5 MiB [=====               ] 27% 1.2s172.5 MiB [======              ] 28% 1.2s172.5 MiB [======              ] 29% 1.1s172.5 MiB [======              ] 31% 1.1s172.5 MiB [=======             ] 32% 1.0s172.5 MiB [=======             ] 34% 1.0s172.5 MiB [=======             ] 34% 1.1s172.5 MiB [=======             ] 35% 1.1s172.5 MiB [=======             ] 36% 1.1s172.5 MiB [========            ] 37% 1.1s172.5 MiB [========            ] 38% 1.0s172.5 MiB [========            ] 40% 1.0s172.5 MiB [========            ] 41% 1.0s172.5 MiB [=========           ] 43% 0.9s172.5 MiB [=========           ] 44% 0.9s172.5 MiB [=========           ] 45% 0.9s172.5 MiB [=========           ] 47% 0.8s172.5 MiB [==========          ] 48% 0.8s172.5 MiB [==========          ] 50% 0.8s172.5 MiB [==========          ] 52% 0.7s172.5 MiB [===========         ] 53% 0.7s172.5 MiB [===========         ] 54% 0.7s172.5 MiB [===========         ] 56% 0.7s172.5 MiB [============        ] 57% 0.6s172.5 MiB [============        ] 59% 0.6s172.5 MiB [============        ] 60% 0.6s172.5 MiB [============        ] 61% 0.6s172.5 MiB [=============       ] 62% 0.6s172.5 MiB [=============       ] 63% 0.6s172.5 MiB [=============       ] 64% 0.6s172.5 MiB [=============       ] 65% 0.5s172.5 MiB [=============       ] 67% 0.5s172.5 MiB [==============      ] 68% 0.5s172.5 MiB [==============      ] 69% 0.5s172.5 MiB [==============      ] 71% 0.4s172.5 MiB [===============     ] 72% 0.4s172.5 MiB [===============     ] 74% 0.4s172.5 MiB [===============     ] 75% 0.4s172.5 MiB [===============     ] 77% 0.3s172.5 MiB [================    ] 79% 0.3s172.5 MiB [================    ] 80% 0.3s172.5 MiB [================    ] 81% 0.3s172.5 MiB [=================   ] 83% 0.2s172.5 MiB [=================   ] 85% 0.2s172.5 MiB [=================   ] 86% 0.2s172.5 MiB [==================  ] 88% 0.2s172.5 MiB [==================  ] 89% 0.1s172.5 MiB [==================  ] 91% 0.1s172.5 MiB [=================== ] 92% 0.1s172.5 MiB [=================== ] 94% 0.1s172.5 MiB [=================== ] 96% 0.1s172.5 MiB [====================] 98% 0.0s172.5 MiB [====================] 99% 0.0s172.5 MiB [====================] 100% 0.0s
# Chromium 139.0.7258.5 (playwright build v1181) downloaded to /root/.cache/ms-playwright/chromium-1181
# Downloading Chromium Headless Shell 139.0.7258.5 (playwright build v1181) from https://cdn.playwright.dev/dbazure/download/playwright/builds/chromium/1181/chromium-headless-shell-linux.zip
# 104.8 MiB [                    ] 0% 0.0s104.8 MiB [                    ] 0% 15.6s104.8 MiB [                    ] 0% 9.4s104.8 MiB [                    ] 0% 5.9s104.8 MiB [                    ] 1% 3.5s104.8 MiB [=                   ] 3% 2.4s104.8 MiB [=                   ] 5% 1.6s104.8 MiB [==                  ] 7% 1.4s104.8 MiB [==                  ] 8% 1.4s104.8 MiB [==                  ] 10% 1.3s104.8 MiB [===                 ] 12% 1.1s104.8 MiB [===                 ] 14% 1.1s104.8 MiB [===                 ] 16% 1.0s104.8 MiB [====                ] 18% 0.9s104.8 MiB [====                ] 21% 0.8s104.8 MiB [=====               ] 23% 0.8s104.8 MiB [=====               ] 26% 0.7s104.8 MiB [======              ] 29% 0.7s104.8 MiB [======              ] 32% 0.6s104.8 MiB [=======             ] 35% 0.6s104.8 MiB [=======             ] 36% 0.6s104.8 MiB [========            ] 40% 0.5s104.8 MiB [=========           ] 43% 0.5s104.8 MiB [=========           ] 47% 0.4s104.8 MiB [==========          ] 49% 0.4s104.8 MiB [==========          ] 52% 0.4s104.8 MiB [===========         ] 55% 0.3s104.8 MiB [============        ] 58% 0.3s104.8 MiB [============        ] 62% 0.3s104.8 MiB [=============       ] 65% 0.2s104.8 MiB [==============      ] 68% 0.2s104.8 MiB [==============      ] 72% 0.2s104.8 MiB [===============     ] 75% 0.2s104.8 MiB [================    ] 78% 0.1s104.8 MiB [================    ] 81% 0.1s104.8 MiB [=================   ] 84% 0.1s104.8 MiB [==================  ] 87% 0.1s104.8 MiB [==================  ] 91% 0.1s104.8 MiB [=================== ] 93% 0.0s104.8 MiB [=================== ] 97% 0.0s104.8 MiB [====================] 100% 0.0s
# Chromium Headless Shell 139.0.7258.5 (playwright build v1181) downloaded to /root/.cache/ms-playwright/chromium_headless_shell-1181
# Downloading Firefox 140.0.2 (playwright build v1489) from https://cdn.playwright.dev/dbazure/download/playwright/builds/firefox/1489/firefox-ubuntu-22.04.zip
# 92.5 MiB [                    ] 0% 0.0s92.5 MiB [                    ] 0% 14.3s92.5 MiB [                    ] 0% 7.7s92.5 MiB [                    ] 0% 5.7s92.5 MiB [                    ] 2% 3.4s92.5 MiB [=                   ] 3% 2.9s92.5 MiB [=                   ] 4% 2.1s92.5 MiB [=                   ] 6% 1.8s92.5 MiB [==                  ] 8% 1.5s92.5 MiB [==                  ] 9% 1.4s92.5 MiB [==                  ] 11% 1.3s92.5 MiB [===                 ] 14% 1.2s92.5 MiB [===                 ] 15% 1.1s92.5 MiB [====                ] 17% 1.0s92.5 MiB [====                ] 20% 0.9s92.5 MiB [=====               ] 22% 0.9s92.5 MiB [=====               ] 25% 0.8s92.5 MiB [======              ] 28% 0.7s92.5 MiB [======              ] 31% 0.7s92.5 MiB [=======             ] 34% 0.6s92.5 MiB [========            ] 37% 0.5s92.5 MiB [========            ] 41% 0.5s92.5 MiB [=========           ] 44% 0.5s92.5 MiB [=========           ] 45% 0.5s92.5 MiB [=========           ] 46% 0.5s92.5 MiB [==========          ] 48% 0.5s92.5 MiB [==========          ] 49% 0.5s92.5 MiB [==========          ] 51% 0.5s92.5 MiB [===========         ] 54% 0.4s92.5 MiB [===========         ] 56% 0.4s92.5 MiB [============        ] 58% 0.4s92.5 MiB [============        ] 61% 0.3s92.5 MiB [=============       ] 65% 0.3s92.5 MiB [==============      ] 68% 0.3s92.5 MiB [==============      ] 71% 0.2s92.5 MiB [===============     ] 74% 0.2s92.5 MiB [===============     ] 76% 0.2s92.5 MiB [================    ] 77% 0.2s92.5 MiB [================    ] 78% 0.2s92.5 MiB [================    ] 81% 0.2s92.5 MiB [================    ] 82% 0.2s92.5 MiB [=================   ] 83% 0.1s92.5 MiB [=================   ] 84% 0.1s92.5 MiB [=================   ] 86% 0.1s92.5 MiB [==================  ] 88% 0.1s92.5 MiB [==================  ] 91% 0.1s92.5 MiB [=================== ] 93% 0.1s92.5 MiB [=================== ] 96% 0.0s92.5 MiB [=================== ] 97% 0.0s92.5 MiB [====================] 98% 0.0s92.5 MiB [====================] 99% 0.0s92.5 MiB [====================] 100% 0.0s
# Firefox 140.0.2 (playwright build v1489) downloaded to /root/.cache/ms-playwright/firefox-1489
# Downloading Webkit 26.0 (playwright build v2191) from https://cdn.playwright.dev/dbazure/download/playwright/builds/webkit/2191/webkit-ubuntu-22.04.zip
# 94.4 MiB [                    ] 0% 0.0s94.4 MiB [                    ] 0% 11.9s94.4 MiB [                    ] 0% 8.6s94.4 MiB [                    ] 0% 5.1s94.4 MiB [                    ] 2% 3.6s94.4 MiB [=                   ] 2% 3.1s94.4 MiB [=                   ] 3% 2.9s94.4 MiB [=                   ] 4% 2.8s94.4 MiB [=                   ] 6% 2.2s94.4 MiB [==                  ] 7% 1.8s94.4 MiB [==                  ] 9% 1.7s94.4 MiB [==                  ] 11% 1.5s94.4 MiB [===                 ] 13% 1.3s94.4 MiB [===                 ] 16% 1.2s94.4 MiB [====                ] 18% 1.2s94.4 MiB [====                ] 20% 1.1s94.4 MiB [=====               ] 23% 1.0s94.4 MiB [=====               ] 25% 0.9s94.4 MiB [======              ] 28% 0.8s94.4 MiB [======              ] 31% 0.7s94.4 MiB [=======             ] 33% 0.7s94.4 MiB [=======             ] 36% 0.7s94.4 MiB [========            ] 39% 0.6s94.4 MiB [========            ] 40% 0.6s94.4 MiB [========            ] 41% 0.6s94.4 MiB [=========           ] 44% 0.6s94.4 MiB [=========           ] 46% 0.5s94.4 MiB [==========          ] 49% 0.5s94.4 MiB [==========          ] 50% 0.5s94.4 MiB [==========          ] 51% 0.5s94.4 MiB [==========          ] 52% 0.5s94.4 MiB [===========         ] 53% 0.5s94.4 MiB [===========         ] 56% 0.4s94.4 MiB [============        ] 59% 0.4s94.4 MiB [============        ] 61% 0.4s94.4 MiB [=============       ] 63% 0.4s94.4 MiB [=============       ] 65% 0.3s94.4 MiB [==============      ] 68% 0.3s94.4 MiB [==============      ] 72% 0.3s94.4 MiB [===============     ] 75% 0.2s94.4 MiB [================    ] 79% 0.2s94.4 MiB [================    ] 81% 0.2s94.4 MiB [=================   ] 84% 0.1s94.4 MiB [=================   ] 86% 0.1s94.4 MiB [==================  ] 87% 0.1s94.4 MiB [==================  ] 89% 0.1s94.4 MiB [==================  ] 92% 0.1s94.4 MiB [=================== ] 95% 0.0s94.4 MiB [=================== ] 97% 0.0s94.4 MiB [====================] 99% 0.0s94.4 MiB [====================] 100% 0.0s
# Webkit 26.0 (playwright build v2191) downloaded to /root/.cache/ms-playwright/webkit-2191
# Downloading FFMPEG playwright build v1011 from https://cdn.playwright.dev/dbazure/download/playwright/builds/ffmpeg/1011/ffmpeg-linux.zip
# 2.3 MiB [                    ] 0% 0.0s2.3 MiB [=                   ] 6% 0.3s2.3 MiB [===                 ] 16% 0.2s2.3 MiB [========            ] 42% 0.1s2.3 MiB [=================== ] 94% 0.0s2.3 MiB [====================] 100% 0.0s
# FFMPEG playwright build v1011 downloaded to /root/.cache/ms-playwright/ffmpeg-1011
# Playwright Host validation warning:
# ╔══════════════════════════════════════════════════════╗
# ║ Host system is missing dependencies to run browsers. ║
# ║ Missing libraries:                                   ║
# ║     libwoff2dec.so.1.0.2                             ║
# ║     libgstgl-1.0.so.0                                ║
# ║     libgstcodecparsers-1.0.so.0                      ║
# ║     libavif.so.13                                    ║
# ║     libharfbuzz-icu.so.0                             ║
# ║     libenchant-2.so.2                                ║
# ║     libsecret-1.so.0                                 ║
# ║     libhyphen.so.0                                   ║
# ║     libmanette-0.2.so.0                              ║
# ╚══════════════════════════════════════════════════════╝
#     at validateDependenciesLinux (/usr/local/lib/python3.11/dist-packages/playwright/driver/package/lib/server/registry/dependencies.js:269:9)
#     at process.processTicksAndRejections (node:internal/process/task_queues:105:5)
#     at async Registry._validateHostRequirements (/usr/local/lib/python3.11/dist-packages/playwright/driver/package/lib/server/registry/index.js:914:14)
#     at async Registry._validateHostRequirementsForExecutableIfNeeded (/usr/local/lib/python3.11/dist-packages/playwright/driver/package/lib/server/registry/index.js:1036:7)
#     at async Registry.validateHostRequirementsForExecutablesIfNeeded (/usr/local/lib/python3.11/dist-packages/playwright/driver/package/lib/server/registry/index.js:1025:7)
#     at async i.<anonymous> (/usr/local/lib/python3.11/dist-packages/playwright/driver/package/lib/cli/program.js:222:7)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from urllib.parse import urlparse, parse_qs
import nest_asyncio
import asyncio
from playwright.async_api import async_playwright, TimeoutError as PlaywrightTimeout

nest_asyncio.apply()

# %%
# Step 1: Fetch Static Job Listing Info
def fetch_jobs_from_page(page_number, fcat_id):
    url = f'https://jobs.bdjobs.com/jobsearch.asp?fcatId={fcat_id}&icatId=&pg={page_number}'
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    return soup

# %%
# Step 2: Scrape Static Data
def scrape_static_data(num_pages=8, category_ids=range(61, 100)):
    job_details = []
    for fcat_id in category_ids:
        for page in range(1, num_pages + 1):
            soup = fetch_jobs_from_page(page, fcat_id)
            jobs = soup.find_all('div', class_=['norm-jobs-wrapper', 'sout-jobs-wrapper'])
            print(f"fcat_id {fcat_id}, Page {page}: Found {len(jobs)} jobs")

            for job in jobs:
                title_div = job.find('div', class_='job-title-text')
                title_a = title_div.find('a') if title_div else None
                job_link = title_a['href'] if title_a and title_a.has_attr('href') else 'N/A'
                parsed = urlparse(job_link)
                q = parse_qs(parsed.query)

                job_details.append({
                    "Title": title_a.get_text(strip=True) if title_a else 'N/A',
                    "Job Link": job_link,
                    "Job ID": q.get('id', ['N/A'])[0],
                    "Job Category ID": q.get('fcatId', ['N/A'])[0],
                    "Company Name": job.find('div', class_='comp-name-text').get_text(strip=True) if job.find('div', class_='comp-name-text') else 'N/A',
                    "Promotion Text": job.find('div', class_='promo-text').get_text(strip=True) if job.find('div', class_='promo-text') else 'N/A',
                    "Location": job.find('div', class_='locon-text-d').get_text(strip=True) if job.find('div', class_='locon-text-d') else 'N/A',
                    "Experience Required": job.find('div', class_='exp-text-d').get_text(strip=True) if job.find('div', class_='exp-text-d') else 'N/A',
                    "Deadline": job.find('div', class_='dead-text-d').get_text(strip=True) if job.find('div', class_='dead-text-d') else 'N/A'
                })
    return pd.DataFrame(job_details)

# %%
# Step 3: Scrap Dynamic Data
async def fetch_dynamic_data(page, link):
    job_data = {
        "Job Link": link,
        "Vacancy": "N/A",
        "Age": "N/A",
        "Job Location": "N/A",
        "Salary": "N/A",
        "Experience": "N/A",
        "Published": "N/A",
        "Additional Requirements": "N/A",
        "Education": "N/A",
        "Remuneration Package": "N/A",
        "Employment Status": "N/A",
        "Gender": "N/A"
    }

    try:
        await page.goto(link, timeout=60000)
        await page.wait_for_selector('#allSection', timeout=5000)
        html = await page.content()
        soup = BeautifulSoup(html, 'html.parser')

        # Section: #allSection
        section = soup.find('div', id='allSection')
        if section:
            for div in section.find_all('div', recursive=True):
                text = div.get_text(separator=' ', strip=True)
                if 'Vacancy:' in text:
                    job_data["Vacancy"] = text.replace('Vacancy:', '').strip()
                elif 'Age:' in text:
                    job_data["Age"] = text.replace('Age:', '').strip()
                elif 'Location:' in text:
                    job_data["Job Location (Dynamic)"] = text.replace('Location:', '').strip()
                elif 'Salary:' in text:
                    job_data["Salary"] = text.replace('Salary:', '').strip()
                elif 'Experience:' in text:
                    job_data["Experience (Dynamic)"] = text.replace('Experience:', '').strip()
                elif 'Published:' in text:
                    job_data["Published"] = text.replace('Published:', '').strip()

        # Section: Education and Additional Requirements
        requirements_div = soup.find('div', id='requirements')
        if requirements_div:
            # Education
            edu_block = requirements_div.find('p', string='Education')
            if edu_block:
                ul = edu_block.find_next('ul')
                if ul:
                    items = [li.get_text(strip=True) for li in ul.find_all('li')]
                    job_data["Education"] = "; ".join(items)

            # Additional Requirements
            add_block = requirements_div.find('p', string='Additional Requirements')
            if add_block:
                sibling_divs = add_block.find_next_siblings('div')
                if sibling_divs:
                    all_lis = []
                    for div in sibling_divs:
                        all_lis += [li.get_text(strip=True) for li in div.find_all('li')]
                    job_data["Additional Requirements"] = "; ".join(all_lis)

        # Remuneration Package
        salary_section = soup.find('div', id='salary')
        if salary_section:
            ul = salary_section.find('ul')
            if ul:
                rem_texts = [li.get_text(strip=True) for li in ul.find_all('li')]
                job_data["Remuneration Package"] = "; ".join(rem_texts)

        # Employment Status
        emp_status_label = soup.find('p', string='Employment Status')
        if emp_status_label:
            emp_status_value = emp_status_label.find_next('p')
            if emp_status_value:
                job_data["Employment Status"] = emp_status_value.get_text(strip=True)

        # Gender
        gender_label = soup.find('p', string='Gender')
        if gender_label:
            gender_value = gender_label.find_next('p')
            if gender_value:
                job_data["Gender"] = gender_value.get_text(strip=True)

    except Exception as e:
        print(f"Error on {link}: {e}")
    except PlaywrightTimeout:
        print(f"Timeout: {link}")

    return job_data

# %%
# Step 4: Use asyncio.gather for concurrency
async def scrape_dynamic_data_concurrent(job_links, concurrency=5):
    results = []
    semaphore = asyncio.Semaphore(concurrency)

    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        context = await browser.new_context()

        async def bound_scrape(link):
            async with semaphore:
                page = await context.new_page()
                data = await fetch_dynamic_data(page, link)
                await page.close()
                return data

        tasks = [bound_scrape(link) for link in job_links]
        results = await asyncio.gather(*tasks)

        await browser.close()
    return pd.DataFrame(results)

# %%
# Step 5: Run Entire Pipeline
async def run_full_scraper():
    static_df = scrape_static_data(num_pages=8, category_ids=range(61, 100))
    job_links = static_df['Job Link'].dropna().unique().tolist()
    dynamic_df = await scrape_dynamic_data_concurrent(job_links, concurrency=5)
    final_df = pd.merge(static_df, dynamic_df, on='Job Link', how='left')
    final_df.to_csv("bdjobs_scraped_data.csv", index=False)
    print("Scraping complete. Data saved to 'bdjobs_scraped_data.csv'")
    return final_df

# %%
# Run the script
await run_full_scraper()
# Out:
# fcat_id 61, Page 1: Found 30 jobs
# fcat_id 61, Page 2: Found 0 jobs
# fcat_id 61, Page 3: Found 0 jobs
# fcat_id 61, Page 4: Found 0 jobs
# fcat_id 61, Page 5: Found 0 jobs
# fcat_id 61, Page 6: Found 0 jobs
# fcat_id 61, Page 7: Found 0 jobs
# fcat_id 61, Page 8: Found 0 jobs
# fcat_id 62, Page 1: Found 50 jobs
# fcat_id 62, Page 2: Found 9 jobs
# fcat_id 62, Page 3: Found 0 jobs
# fcat_id 62, Page 4: Found 0 jobs
# fcat_id 62, Page 5: Found 0 jobs
# fcat_id 62, Page 6: Found 0 jobs
# fcat_id 62, Page 7: Found 0 jobs
# fcat_id 62, Page 8: Found 0 jobs
# fcat_id 63, Page 1: Found 48 jobs
# fcat_id 63, Page 2: Found 0 jobs
# fcat_id 63, Page 3: Found 0 jobs
# fcat_id 63, Page 4: Found 0 jobs
# fcat_id 63, Page 5: Found 0 jobs
# fcat_id 63, Page 6: Found 0 jobs
# fcat_id 63, Page 7: Found 0 jobs
# fcat_id 63, Page 8: Found 0 jobs
# fcat_id 64, Page 1: Found 17 jobs
# fcat_id 64, Page 2: Found 0 jobs
# fcat_id 64, Page 3: Found 0 jobs
# fcat_id 64, Page 4: Found 0 jobs
# fcat_id 64, Page 5: Found 0 jobs
# fcat_id 64, Page 6: Found 0 jobs
# fcat_id 64, Page 7: Found 0 jobs
# fcat_id 64, Page 8: Found 0 jobs
# fcat_id 65, Page 1: Found 18 jobs
# fcat_id 65, Page 2: Found 0 jobs
# fcat_id 65, Page 3: Found 0 jobs
# fcat_id 65, Page 4: Found 0 jobs
# fcat_id 65, Page 5: Found 0 jobs
# fcat_id 65, Page 6: Found 0 jobs
# fcat_id 65, Page 7: Found 0 jobs
# fcat_id 65, Page 8: Found 0 jobs
# fcat_id 66, Page 1: Found 38 jobs
# fcat_id 66, Page 2: Found 0 jobs
# fcat_id 66, Page 3: Found 0 jobs
# fcat_id 66, Page 4: Found 0 jobs
# fcat_id 66, Page 5: Found 0 jobs
# fcat_id 66, Page 6: Found 0 jobs
# fcat_id 66, Page 7: Found 0 jobs
# fcat_id 66, Page 8: Found 0 jobs
# fcat_id 67, Page 1: Found 48 jobs
# fcat_id 67, Page 2: Found 0 jobs
# fcat_id 67, Page 3: Found 0 jobs
# fcat_id 67, Page 4: Found 0 jobs
# fcat_id 67, Page 5: Found 0 jobs
# fcat_id 67, Page 6: Found 0 jobs
# fcat_id 67, Page 7: Found 0 jobs
# fcat_id 67, Page 8: Found 0 jobs
# fcat_id 68, Page 1: Found 42 jobs
# fcat_id 68, Page 2: Found 0 jobs
# fcat_id 68, Page 3: Found 0 jobs
# fcat_id 68, Page 4: Found 0 jobs
# fcat_id 68, Page 5: Found 0 jobs
# fcat_id 68, Page 6: Found 0 jobs
# fcat_id 68, Page 7: Found 0 jobs
# fcat_id 68, Page 8: Found 0 jobs
# fcat_id 69, Page 1: Found 8 jobs
# fcat_id 69, Page 2: Found 0 jobs
# fcat_id 69, Page 3: Found 0 jobs
# fcat_id 69, Page 4: Found 0 jobs
# fcat_id 69, Page 5: Found 0 jobs
# fcat_id 69, Page 6: Found 0 jobs
# fcat_id 69, Page 7: Found 0 jobs
# fcat_id 69, Page 8: Found 0 jobs
# fcat_id 70, Page 1: Found 38 jobs
# fcat_id 70, Page 2: Found 0 jobs
# fcat_id 70, Page 3: Found 0 jobs
# fcat_id 70, Page 4: Found 0 jobs
# fcat_id 70, Page 5: Found 0 jobs
# fcat_id 70, Page 6: Found 0 jobs
# fcat_id 70, Page 7: Found 0 jobs
# fcat_id 70, Page 8: Found 0 jobs
# fcat_id 71, Page 1: Found 49 jobs
# fcat_id 71, Page 2: Found 29 jobs
# fcat_id 71, Page 3: Found 0 jobs
# fcat_id 71, Page 4: Found 0 jobs
# fcat_id 71, Page 5: Found 0 jobs
# fcat_id 71, Page 6: Found 0 jobs
# fcat_id 71, Page 7: Found 0 jobs
# fcat_id 71, Page 8: Found 0 jobs
# fcat_id 72, Page 1: Found 4 jobs
# fcat_id 72, Page 2: Found 0 jobs
# fcat_id 72, Page 3: Found 0 jobs
# fcat_id 72, Page 4: Found 0 jobs
# fcat_id 72, Page 5: Found 0 jobs
# fcat_id 72, Page 6: Found 0 jobs
# fcat_id 72, Page 7: Found 0 jobs
# fcat_id 72, Page 8: Found 0 jobs
# fcat_id 73, Page 1: Found 11 jobs
# fcat_id 73, Page 2: Found 0 jobs
# fcat_id 73, Page 3: Found 0 jobs
# fcat_id 73, Page 4: Found 0 jobs
# fcat_id 73, Page 5: Found 0 jobs
# fcat_id 73, Page 6: Found 0 jobs
# fcat_id 73, Page 7: Found 0 jobs
# fcat_id 73, Page 8: Found 0 jobs
# fcat_id 74, Page 1: Found 1 jobs
# fcat_id 74, Page 2: Found 0 jobs
# fcat_id 74, Page 3: Found 0 jobs
# fcat_id 74, Page 4: Found 0 jobs
# fcat_id 74, Page 5: Found 0 jobs
# fcat_id 74, Page 6: Found 0 jobs
# fcat_id 74, Page 7: Found 0 jobs
# fcat_id 74, Page 8: Found 0 jobs
# fcat_id 75, Page 1: Found 30 jobs
# fcat_id 75, Page 2: Found 0 jobs
# fcat_id 75, Page 3: Found 0 jobs
# fcat_id 75, Page 4: Found 0 jobs
# fcat_id 75, Page 5: Found 0 jobs
# fcat_id 75, Page 6: Found 0 jobs
# fcat_id 75, Page 7: Found 0 jobs
# fcat_id 75, Page 8: Found 0 jobs
# fcat_id 76, Page 1: Found 7 jobs
# fcat_id 76, Page 2: Found 0 jobs
# fcat_id 76, Page 3: Found 0 jobs
# fcat_id 76, Page 4: Found 0 jobs
# fcat_id 76, Page 5: Found 0 jobs
# fcat_id 76, Page 6: Found 0 jobs
# fcat_id 76, Page 7: Found 0 jobs
# fcat_id 76, Page 8: Found 0 jobs
# fcat_id 77, Page 1: Found 20 jobs
# fcat_id 77, Page 2: Found 0 jobs
# fcat_id 77, Page 3: Found 0 jobs
# fcat_id 77, Page 4: Found 0 jobs
# fcat_id 77, Page 5: Found 0 jobs
# fcat_id 77, Page 6: Found 0 jobs
# fcat_id 77, Page 7: Found 0 jobs
# fcat_id 77, Page 8: Found 0 jobs
# fcat_id 78, Page 1: Found 14 jobs
# fcat_id 78, Page 2: Found 0 jobs
# fcat_id 78, Page 3: Found 0 jobs
# fcat_id 78, Page 4: Found 0 jobs
# fcat_id 78, Page 5: Found 0 jobs
# fcat_id 78, Page 6: Found 0 jobs
# fcat_id 78, Page 7: Found 0 jobs
# fcat_id 78, Page 8: Found 0 jobs
# fcat_id 79, Page 1: Found 50 jobs
# fcat_id 79, Page 2: Found 7 jobs
# fcat_id 79, Page 3: Found 0 jobs
# fcat_id 79, Page 4: Found 0 jobs
# fcat_id 79, Page 5: Found 0 jobs
# fcat_id 79, Page 6: Found 0 jobs
# fcat_id 79, Page 7: Found 0 jobs
# fcat_id 79, Page 8: Found 0 jobs
# fcat_id 80, Page 1: Found 36 jobs
# fcat_id 80, Page 2: Found 0 jobs
# fcat_id 80, Page 3: Found 0 jobs
# fcat_id 80, Page 4: Found 0 jobs
# fcat_id 80, Page 5: Found 0 jobs
# fcat_id 80, Page 6: Found 0 jobs
# fcat_id 80, Page 7: Found 0 jobs
# fcat_id 80, Page 8: Found 0 jobs
# fcat_id 81, Page 1: Found 2 jobs
# fcat_id 81, Page 2: Found 0 jobs
# fcat_id 81, Page 3: Found 0 jobs
# fcat_id 81, Page 4: Found 0 jobs
# fcat_id 81, Page 5: Found 0 jobs
# fcat_id 81, Page 6: Found 0 jobs
# fcat_id 81, Page 7: Found 0 jobs
# fcat_id 81, Page 8: Found 0 jobs
# fcat_id 82, Page 1: Found 6 jobs
# fcat_id 82, Page 2: Found 0 jobs
# fcat_id 82, Page 3: Found 0 jobs
# fcat_id 82, Page 4: Found 0 jobs
# fcat_id 82, Page 5: Found 0 jobs
# fcat_id 82, Page 6: Found 0 jobs
# fcat_id 82, Page 7: Found 0 jobs
# fcat_id 82, Page 8: Found 0 jobs
# fcat_id 83, Page 1: Found 31 jobs
# fcat_id 83, Page 2: Found 0 jobs
# fcat_id 83, Page 3: Found 0 jobs
# fcat_id 83, Page 4: Found 0 jobs
# fcat_id 83, Page 5: Found 0 jobs
# fcat_id 83, Page 6: Found 0 jobs
# fcat_id 83, Page 7: Found 0 jobs
# fcat_id 83, Page 8: Found 0 jobs
# fcat_id 84, Page 1: Found 30 jobs
# fcat_id 84, Page 2: Found 0 jobs
# fcat_id 84, Page 3: Found 0 jobs
# fcat_id 84, Page 4: Found 0 jobs
# fcat_id 84, Page 5: Found 0 jobs
# fcat_id 84, Page 6: Found 0 jobs
# fcat_id 84, Page 7: Found 0 jobs
# fcat_id 84, Page 8: Found 0 jobs
# fcat_id 85, Page 1: Found 2 jobs
# fcat_id 85, Page 2: Found 0 jobs
# fcat_id 85, Page 3: Found 0 jobs
# fcat_id 85, Page 4: Found 0 jobs
# fcat_id 85, Page 5: Found 0 jobs
# fcat_id 85, Page 6: Found 0 jobs
# fcat_id 85, Page 7: Found 0 jobs
# fcat_id 85, Page 8: Found 0 jobs
# fcat_id 86, Page 1: Found 2 jobs
# fcat_id 86, Page 2: Found 0 jobs
# fcat_id 86, Page 3: Found 0 jobs
# fcat_id 86, Page 4: Found 0 jobs
# fcat_id 86, Page 5: Found 0 jobs
# fcat_id 86, Page 6: Found 0 jobs
# fcat_id 86, Page 7: Found 0 jobs
# fcat_id 86, Page 8: Found 0 jobs
# fcat_id 87, Page 1: Found 14 jobs
# fcat_id 87, Page 2: Found 0 jobs
# fcat_id 87, Page 3: Found 0 jobs
# fcat_id 87, Page 4: Found 0 jobs
# fcat_id 87, Page 5: Found 0 jobs
# fcat_id 87, Page 6: Found 0 jobs
# fcat_id 87, Page 7: Found 0 jobs
# fcat_id 87, Page 8: Found 0 jobs
# fcat_id 88, Page 1: Found 5 jobs
# fcat_id 88, Page 2: Found 0 jobs
# fcat_id 88, Page 3: Found 0 jobs
# fcat_id 88, Page 4: Found 0 jobs
# fcat_id 88, Page 5: Found 0 jobs
# fcat_id 88, Page 6: Found 0 jobs
# fcat_id 88, Page 7: Found 0 jobs
# fcat_id 88, Page 8: Found 0 jobs
# fcat_id 89, Page 1: Found 9 jobs
# fcat_id 89, Page 2: Found 0 jobs
# fcat_id 89, Page 3: Found 0 jobs
# fcat_id 89, Page 4: Found 0 jobs
# fcat_id 89, Page 5: Found 0 jobs
# fcat_id 89, Page 6: Found 0 jobs
# fcat_id 89, Page 7: Found 0 jobs
# fcat_id 89, Page 8: Found 0 jobs
# fcat_id 90, Page 1: Found 4 jobs
# fcat_id 90, Page 2: Found 0 jobs
# fcat_id 90, Page 3: Found 0 jobs
# fcat_id 90, Page 4: Found 0 jobs
# fcat_id 90, Page 5: Found 0 jobs
# fcat_id 90, Page 6: Found 0 jobs
# fcat_id 90, Page 7: Found 0 jobs
# fcat_id 90, Page 8: Found 0 jobs
# fcat_id 91, Page 1: Found 8 jobs
# fcat_id 91, Page 2: Found 0 jobs
# fcat_id 91, Page 3: Found 0 jobs
# fcat_id 91, Page 4: Found 0 jobs
# fcat_id 91, Page 5: Found 0 jobs
# fcat_id 91, Page 6: Found 0 jobs
# fcat_id 91, Page 7: Found 0 jobs
# fcat_id 91, Page 8: Found 0 jobs
# fcat_id 92, Page 1: Found 6 jobs
# fcat_id 92, Page 2: Found 0 jobs
# fcat_id 92, Page 3: Found 0 jobs
# fcat_id 92, Page 4: Found 0 jobs
# fcat_id 92, Page 5: Found 0 jobs
# fcat_id 92, Page 6: Found 0 jobs
# fcat_id 92, Page 7: Found 0 jobs
# fcat_id 92, Page 8: Found 0 jobs
# fcat_id 93, Page 1: Found 0 jobs
# fcat_id 93, Page 2: Found 0 jobs
# fcat_id 93, Page 3: Found 0 jobs
# fcat_id 93, Page 4: Found 0 jobs
# fcat_id 93, Page 5: Found 0 jobs
# fcat_id 93, Page 6: Found 0 jobs
# fcat_id 93, Page 7: Found 0 jobs
# fcat_id 93, Page 8: Found 0 jobs
# fcat_id 94, Page 1: Found 0 jobs
# fcat_id 94, Page 2: Found 0 jobs
# fcat_id 94, Page 3: Found 0 jobs
# fcat_id 94, Page 4: Found 0 jobs
# fcat_id 94, Page 5: Found 0 jobs
# fcat_id 94, Page 6: Found 0 jobs
# fcat_id 94, Page 7: Found 0 jobs
# fcat_id 94, Page 8: Found 0 jobs
# fcat_id 95, Page 1: Found 0 jobs
# fcat_id 95, Page 2: Found 0 jobs
# fcat_id 95, Page 3: Found 0 jobs
# fcat_id 95, Page 4: Found 0 jobs
# fcat_id 95, Page 5: Found 0 jobs
# fcat_id 95, Page 6: Found 0 jobs
# fcat_id 95, Page 7: Found 0 jobs
# fcat_id 95, Page 8: Found 0 jobs
# fcat_id 96, Page 1: Found 0 jobs
# fcat_id 96, Page 2: Found 0 jobs
# fcat_id 96, Page 3: Found 0 jobs
# fcat_id 96, Page 4: Found 0 jobs
# fcat_id 96, Page 5: Found 0 jobs
# fcat_id 96, Page 6: Found 0 jobs
# fcat_id 96, Page 7: Found 0 jobs
# fcat_id 96, Page 8: Found 0 jobs
# fcat_id 97, Page 1: Found 0 jobs
# fcat_id 97, Page 2: Found 0 jobs
# fcat_id 97, Page 3: Found 0 jobs
# fcat_id 97, Page 4: Found 0 jobs
# fcat_id 97, Page 5: Found 0 jobs
# fcat_id 97, Page 6: Found 0 jobs
# fcat_id 97, Page 7: Found 0 jobs
# fcat_id 97, Page 8: Found 0 jobs
# fcat_id 98, Page 1: Found 0 jobs
# fcat_id 98, Page 2: Found 0 jobs
# fcat_id 98, Page 3: Found 0 jobs
# fcat_id 98, Page 4: Found 0 jobs
# fcat_id 98, Page 5: Found 0 jobs
# fcat_id 98, Page 6: Found 0 jobs
# fcat_id 98, Page 7: Found 0 jobs
# fcat_id 98, Page 8: Found 0 jobs
# fcat_id 99, Page 1: Found 0 jobs
# fcat_id 99, Page 2: Found 0 jobs
# fcat_id 99, Page 3: Found 0 jobs
# fcat_id 99, Page 4: Found 0 jobs
# fcat_id 99, Page 5: Found 0 jobs
# fcat_id 99, Page 6: Found 0 jobs
# fcat_id 99, Page 7: Found 0 jobs
# fcat_id 99, Page 8: Found 0 jobs
# Error on https://jobs.bdjobs.com/jobdetails/?id=1387641&fcatId=61&ln=1: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280715&fcatId=61&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280602&fcatId=62&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280601&fcatId=62&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280556&fcatId=62&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280552&fcatId=62&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280494&fcatId=62&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280488&fcatId=62&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#     - waiting for" https://jobs.bdjobs.com/jobviewimg.asp?id=280488" navigation to finish...
#     - navigated to "https://jobs.bdjobs.com/jobviewimg.asp?id=280488"
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280487&fcatId=62&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280485&fcatId=62&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280483&fcatId=62&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280484&fcatId=62&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280475&fcatId=62&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280453&fcatId=62&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#     - waiting for" https://jobs.bdjobs.com/jobviewimg.asp?id=280453" navigation to finish...
#     - navigated to "https://jobs.bdjobs.com/jobviewimg.asp?id=280453"
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280433&fcatId=62&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280452&fcatId=62&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280426&fcatId=62&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280429&fcatId=62&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280385&fcatId=62&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280476&fcatId=65&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280718&fcatId=66&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280635&fcatId=66&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280505&fcatId=66&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280456&fcatId=66&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280421&fcatId=66&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280197&fcatId=66&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280198&fcatId=66&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280196&fcatId=66&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280703&fcatId=67&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280695&fcatId=67&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280637&fcatId=67&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280714&fcatId=67&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280603&fcatId=67&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#     - waiting for" https://jobs.bdjobs.com/jobviewimg.asp?id=280603" navigation to finish...
#     - navigated to "https://jobs.bdjobs.com/jobviewimg.asp?id=280603"
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280617&fcatId=67&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280492&fcatId=67&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280437&fcatId=67&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280585&fcatId=67&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280422&fcatId=67&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280397&fcatId=67&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#     - waiting for" https://jobs.bdjobs.com/jobviewimg.asp?id=280397" navigation to finish...
#     - navigated to "https://jobs.bdjobs.com/jobviewimg.asp?id=280397"
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280387&fcatId=67&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280237&fcatId=67&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280194&fcatId=67&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=1390974&fcatId=68&ln=1: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=1391154&fcatId=68&ln=1: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=1390586&fcatId=68&ln=1: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280555&fcatId=68&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280519&fcatId=68&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280513&fcatId=68&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280512&fcatId=68&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280554&fcatId=69&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280719&fcatId=70&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280620&fcatId=70&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280554&fcatId=70&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280510&fcatId=70&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280489&fcatId=70&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280480&fcatId=70&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#     - waiting for" https://jobs.bdjobs.com/jobviewimg.asp?id=280480" navigation to finish...
#     - navigated to "https://jobs.bdjobs.com/jobviewimg.asp?id=280480"
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280435&fcatId=70&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280423&fcatId=70&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280400&fcatId=70&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280417&fcatId=70&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280334&fcatId=70&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280195&fcatId=70&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280416&fcatId=72&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280638&fcatId=73&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280558&fcatId=75&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280720&fcatId=79&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280713&fcatId=79&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280704&fcatId=79&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280639&fcatId=79&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280636&fcatId=79&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280619&fcatId=79&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280620&fcatId=79&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280618&fcatId=79&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280562&fcatId=79&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280559&fcatId=79&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280551&fcatId=79&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280520&fcatId=79&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280518&fcatId=79&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280509&fcatId=79&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280502&fcatId=79&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280454&fcatId=79&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280455&fcatId=79&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280501&fcatId=79&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280434&fcatId=79&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280500&fcatId=79&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280398&fcatId=79&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#     - waiting for" https://jobs.bdjobs.com/jobviewimg.asp?id=280398" navigation to finish...
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280386&fcatId=79&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#     - waiting for" https://jobs.bdjobs.com/jobviewimg.asp?id=280386" navigation to finish...
#     - navigated to "https://jobs.bdjobs.com/jobviewimg.asp?id=280386"
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280330&fcatId=79&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#     - waiting for" https://jobs.bdjobs.com/jobviewimg.asp?id=280330" navigation to finish...
#     - navigated to "https://jobs.bdjobs.com/jobviewimg.asp?id=280330"
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280304&fcatId=79&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#     - waiting for" https://jobs.bdjobs.com/jobviewimg.asp?id=280304" navigation to finish...
#     - navigated to "https://jobs.bdjobs.com/jobviewimg.asp?id=280304"
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280303&fcatId=79&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280253&fcatId=79&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280252&fcatId=79&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280200&fcatId=79&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280251&fcatId=79&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280202&fcatId=79&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280201&fcatId=79&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#     - waiting for" https://jobs.bdjobs.com/jobviewimg.asp?id=280201" navigation to finish...
#     - navigated to "https://jobs.bdjobs.com/jobviewimg.asp?id=280201"
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280174&fcatId=79&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280172&fcatId=79&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280173&fcatId=79&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280723&fcatId=80&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280567&fcatId=80&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280521&fcatId=80&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280508&fcatId=80&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280511&fcatId=80&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280436&fcatId=80&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280399&fcatId=80&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280564&fcatId=81&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280175&fcatId=81&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280557&fcatId=82&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280486&fcatId=85&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280506&fcatId=85&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Error on https://jobs.bdjobs.com/jobdetails/?id=280628&fcatId=87&ln=2: Page.wait_for_selector: Timeout 5000ms exceeded.
# Call log:
#   - waiting for locator("#allSection") to be visible
#
# Scraping complete. Data saved to 'bdjobs_scraped_data.csv'
#                                       Title  \
# 0     USG Operator/Medical Transcriptionist
# 1            Lead Generation & Excel Expert
# 2                Computer Operator (Female)
# 3                         কম্পিউটার অপারেটর
# 4                         Computer Operator
# ..                                      ...
# 718  Medical Technologist / Physiotherapist
# 719                     অফিস সহায়ক (পুরুষ)
# 720                Clinical Physiotherapist
# 721    Medical Technologist (Physiotherapy)
# 722    Medical Technologist (Physiotherapy)
#
#                                               Job Link   Job ID  \
# 0    https://jobs.bdjobs.com/jobdetails/?id=1394103...  1394103
# 1    https://jobs.bdjobs.com/jobdetails/?id=1393321...  1393321
# 2    https://jobs.bdjobs.com/jobdetails/?id=1393595...  1393595
# 3    https://jobs.bdjobs.com/jobdetails/?id=1393434...  1393434
# 4    https://jobs.bdjobs.com/jobdetails/?id=1393399...  1393399
# ..                                                 ...      ...
# 718  https://jobs.bdjobs.com/jobdetails/?id=1393356...  1393356
# 719  https://jobs.bdjobs.com/jobdetails/?id=1392652...  1392652
# 720  https://jobs.bdjobs.com/jobdetails/?id=1390739...  1390739
# 721  https://jobs.bdjobs.com/jobdetails/?id=1387833...  1387833
# 722  https://jobs.bdjobs.com/jobdetails/?id=1387816...  1387816
#
#     Job Category ID                                       Company Name  \
# 0                61  Dhaka Central International Medical College & ...
# 1                61                                  M.K.I Outsourcing
# 2                61                                          BAJAJMART
# 3                61  Shaheed Lieutenant Tanzim Cantonment Public Sc...
# 4                61                   Bazlul Huq Khan School & College
# ..              ...                                                ...
# 718              92                Amin Physiotherapy & Fitness Center
# 719              92       E-Learning And Earning Ltd (Barishal Branch)
# 720              92                           Techno Health Bangladesh
# 721              92                    ASPC ManipulationTherapy centre
# 722              92  Physio Sheba Pain, Paralysis Center & Home Ser...
#
#                                         Promotion Text  \
# 0    DCIMCH is a leading healthcare institution com...
# 1                                                  N/A
# 2                                                  N/A
# 3                                                  N/A
# 4
# ..                                                 ...
# 718                                                N/A
# 719                                                N/A
# 720                                                N/A
# 721                                                N/A
# 722
#
#                        Location Experience Required    Deadline Vacancy  ...  \
# 0                      Shyamoli      1 to 3 year(s)  30 Aug2025       2  ...
# 1                  Sylhet Sadar      3 to 5 year(s)  16 Aug2025      --  ...
# 2                  Chirirbandar                  Na  17 Aug2025       2  ...
# 3                          Ramu      2 to 3 year(s)  21 Aug2025      01  ...
# 4                         Dhaka      2 to 4 year(s)  25 Aug2025       2  ...
# ..                          ...                 ...         ...     ...  ...
# 718        Sylhet, Sylhet Sadar                  Na  16 Aug2025       4  ...
# 719              Barishal Sadar  At least 1 year(s)  14 Aug2025       1  ...
# 720              Uttara, Banani      1 to 3 year(s)  28 Aug2025      10  ...
# 721  Mohammadpur, Tangail Sadar                  Na  20 Aug2025       5  ...
# 722                Dhaka, Badda                  Na  19 Aug2025      10  ...
#
#                           Salary Experience    Published  \
# 0                     Negotiable        N/A  09 Aug 2025
# 1                     Negotiable        N/A  07 Aug 2025
# 2    Tk. 12000 - 15000 (Monthly)        N/A  07 Aug 2025
# 3                     Negotiable        N/A  07 Aug 2025
# 4                     Negotiable        N/A  07 Aug 2025
# ..                           ...        ...          ...
# 718  Tk. 15000 - 25000 (Monthly)        N/A  06 Aug 2025
# 719           Tk. 7000 (Monthly)        N/A  04 Aug 2025
# 720  Tk. 20000 - 30000 (Monthly)        N/A  29 Jul 2025
# 721  Tk. 16000 - 20000 (Monthly)        N/A  24 Jul 2025
# 722                   Negotiable        N/A  21 Jul 2025
#
#                                Additional Requirements  \
# 0                                   Age 25 to 35 years
# 1    Age 25 to 35 years; Proficiency in lead genera...
# 2    অভিজ্ঞদের অগ্রাধীকার দেওয়া হবে।; ই-মেইল এবং ইন...
# 3                                   Age 18 to 35 years
# 4    Age 25 to 32 years; Good typing knowledge in b...
# ..                                                 ...
# 718                                 Age 22 to 33 years
# 719  Age At least 18 years; ২৪ ঘন্টা অফিসে থাকা বাধ...
# 720  Age 25 to 35 years; Excellent communication an...
# 721                                                N/A
# 722  অভিজ্ঞতা থাকলে অগ্রাধিকার, তবে নতুনরাও আবেদন ক...
#
#                                              Education  \
# 0                                 HSC; Bachelor/Honors
# 1                                      Bachelor/Honors
# 2                                                  HSC
# 3    HSC; যে কোন বোর্ড হতে এইচএসসি/সমমানসহ সরকার অন...
# 4                                      Bachelor/Honors
# ..                                                 ...
# 718  Bachelor of Science (BSc) in Physiotherapy; Di...
# 719                                 JSC / JDC / 8 pass
# 720                    Bachelor of Physiotherapy (BPT)
# 721      Diploma in Medical Technology (Physiotherapy)
# 722                                            Diploma
#
#                                   Remuneration Package Employment Status  \
# 0    Provident fund,Over time allowance; Salary Rev...         Full Time
# 1        Salary Review: Half Yearly; Festival Bonus: 2         Full Time
# 2                                                              Full Time
# 3                              গ্রেড - ১৬ (৯৩০০-২২৪৯০)         Full Time
# 4    Provident fund; Salary Review: Yearly; Festiva...         Full Time
# ..                                                 ...               ...
# 718                                                N/A         Full Time
# 719           Salary Review: Yearly; Festival Bonus: 2         Full Time
# 720                                                N/A         Full Time
# 721  Performance bonus; Salary Review: Yearly; Fest...         Full Time
# 722                                                            Full Time
#
#           Gender                             Job Location (Dynamic)  \
# 0    Only Female                                   Dhaka (Shyamoli)
# 1      Only Male                              Sylhet (Sylhet Sadar)
# 2    Only Female                            Dinajpur (Chirirbandar)
# 3            N/A                                 Cox`s Bazar (Ramu)
# 4      Only Male                                              Dhaka
# ..           ...                                                ...
# 718          N/A  Sylhet, Sylhet (Sylhet Sa... Sylhet, Sylhet (S...
# 719    Only Male                          Barishal (Barishal Sadar)
# 720  Only Female                             Dhaka (Banani, Uttara)
# 721          N/A  Dhaka (Mohammadpur), Tang... Dhaka (Mohammadpu...
# 722          N/A                               Dhaka, Dhaka (Badda)
#
#     Experience (Dynamic)
# 0           1 to 3 years
# 1           3 to 5 years
# 2                    NaN
# 3           2 to 3 years
# 4           2 to 4 years
# ..                   ...
# 718                  NaN
# 719     At least 1 years
# 720         1 to 3 years
# 721                  NaN
# 722                  NaN
#
# [723 rows x 22 columns]

# %%
from IPython.display import FileLink

FileLink(r'bdjobs_scraped_data.csv')
# Out:
# /kaggle/working/bdjobs_scraped_data.csv
